# %% [markdown]
# # **Intro To PANDAS**
# Used to for Data Manipulation and Analysis.
#
# Simplifies working with structured datasets like tables, spreadsheets, or time-series data.
#
# ### **Series**:
#  one dimensional array that can hold any data type: integers, float, strings or python objects.
#
# each element in a series have unique label called Index
#
# ### **Data Frame**:
# It is a 2 dimensional data structure similar to table and data base.
#
# consist of rows and columns where rows have **indices** (labels) and column have name **labels**.

# %%
import pandas as pd
